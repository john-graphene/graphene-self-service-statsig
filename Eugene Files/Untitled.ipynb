# %%
import pandas as pd

# %%
df=pd.read_excel("Megalabs_Prunelax_v4_150523_edited v2.1.xlsx",sheet_name=None)

# %%
df1=df["Performance"]

# %%
list(df1["Type"].unique())
# Out:
# ['Unmet Needs',
#  'Size',
#  'Drivers of Purchase/Usage',
#  'Profile Markers',
#  'Satisfiers',
#  'Dissatisfiers',
#  'Triggers',
#  'Satisfiers - AI Discovered',
#  'Social issues',
#  'Career issues',
#  'Platforms']

# %%
df1.columns
# Out:
# Index(['PeriodKey', 'Category', 'Subcategory', 'Segment', 'Country', 'Brand',
#        'Type', 'Subtype', 'Content', 'Measure Value', 'Measure Type',
#        'Denominator', 'New data', 'QC Comments'],
#       dtype='object')

# %%
["a"]*5
# Out:
# ['a', 'a', 'a', 'a', 'a']
